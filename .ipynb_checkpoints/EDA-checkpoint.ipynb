# %%
import numpy as np
import re
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
team_lookup = pickle.load(open('teams_lookup.pickle', "rb" ))
df = pickle.load(open('basic_stats.pkl', "rb" ))
adf = pickle.load(open('advanced_stats.pkl', "rb" ))

# %%
len(adf.url.unique())
# Out:
# 5603

# %%
adf.D1.sum()
# Out:
# 11206

# %%
adf.D1.count()
# Out:
# 11206

# %%
adf.columns
# Out:
# Index(['url', 'Team', 'Date', 'Opponent', 'D1', 'Court', 'Home', 'Away', 'PD',
#        'GP', 'Tm', 'Opp', 'ORtg', 'DRtg', 'Pace', 'FTr', '3PAr', 'TS%', 'TRB%',
#        'AST%', 'STL%', 'BLK%', 'OeFG%', 'OTOV%', 'ORB%', 'OFT/FGA', 'DeFG%',
#        'DTOV%', 'DRB%', 'DFT/FGA'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11652 entries, /cbb/boxscores/2018-11-09-23-california.htmlcalifornia to /cbb/boxscores/2019-03-06-19-oakland.htmlyoungstown-state
# Data columns (total 44 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   url       11652 non-null  object
#  1   Team      11652 non-null  object
#  2   Date      11652 non-null  datetime64[ns]
#  3   Opponent  11652 non-null  object
#  4   D1        11652 non-null  int64
#  5   Court     11652 non-null  object
#  6   Home      11652 non-null  uint8
#  7   Away      11652 non-null  uint8
#  8   PD        11652 non-null  int64
#  9   GP        11652 non-null  float64
#  10  Tm        11299 non-null  float64
#  11  Opp       11299 non-null  float64
#  12  FG        11299 non-null  float64
#  13  FGA       11299 non-null  float64
#  14  FG%       11299 non-null  float64
#  15  3P        11299 non-null  float64
#  16  3PA       11299 non-null  float64
# ...

# %%
small_adf =adf.loc[:,['PD','Home','ORtg', 'DRtg', 'Pace', 'FTr', '3PAr', 'TS%', 'TRB%',
       'AST%', 'STL%', 'BLK%']]
ff_adf = adf.loc[:,['PD','Home','OeFG%', 'OTOV%', 'ORB%', 'OFT/FGA', 'DeFG%',
       'DTOV%', 'DRB%', 'DFT/FGA']]

# %%
sns.pairplot(small_adf, plot_kws=dict(alpha=.05, edgecolor='none'))

# %%
plt.hist(adf.GP)
# Out:
# (array([1412., 1412., 1412., 1412., 1412., 1412., 1412., 1301.,  433.,
#           34.]),
#  array([ 0. ,  3.9,  7.8, 11.7, 15.6, 19.5, 23.4, 27.3, 31.2, 35.1, 39. ]),
#  <a list of 10 Patch objects>)

# %%
len(adf.GP)
# Out:
# 11652

# %%
adf.GP.describe()
# Out:
# count    11652.000000
# mean        16.064281
# std          9.630380
# min          0.000000
# 25%          8.000000
# 50%         16.000000
# 75%         24.000000
# max         39.000000
# Name: GP, dtype: float64

# %%
sum(adf['GP'] >= 12)
# Out:
# 7416

# %%
sum(adf['GP'] <= 24) - sum(adf['GP'] < 12)
# Out:
# 4589

# %%
sum(adf['GP'] > 24) - sum(adf['GP'] > 29)
# Out:
# 1757

# %%
sum(adf['GP'] > 29)
# Out:
# 1070

# %%
y = adf.loc[:,['PD']]
X1 = adf.loc[:,['Home','Away','ORtg', 'DRtg', 'Pace', 'FTr', '3PAr', 'TS%', 'TRB%',
       'AST%', 'STL%', 'BLK%']]
X2 = adf.loc[:,['Home','Away','OeFG%', 'OTOV%', 'ORB%', 'OFT/FGA', 'DeFG%',
       'DTOV%', 'DRB%', 'DFT/FGA']]

# %%
def split_and_validate(X,y):
    # perform train/val split
    X_train = X.loc[[12 < x <= 24 for x in adf.loc[:,'GP']],:]
    X_val = X.loc[[24 < x <= 28 for x in adf.loc[:,'GP']],:]
    y_train = y.loc[[12 < x <= 24 for x in adf.loc[:,'GP']],:]
    y_val = y.loc[[24 < x <= 28 for x in adf.loc[:,'GP']],:]

    # fit linear regression to training data
    lr_model = LinearRegression()
    lr_model.fit(X_train, y_train)

    # score fit model on validation data
    val_score = lr_model.score(X_val, y_val)

    print('\nValidation R^2 score was:', val_score)
    
    # report results
    print('Feature coefficient results: \n')
    for feature, coef in zip(X.columns, lr_model.coef_[0]):
        print(feature, ':', coef)

# %%
split_and_validate(X1,y)
# Out:
# Validation R^2 score was: 0.17241990728766776
# Feature coefficient results:
#
# Home : 5.975313113333896
# Away : -0.8565570138199948
# ORtg : 0.30850505766736114
# DRtg : -0.2451872484655912
# Pace : 0.01474525301309141
# FTr : -8.622968543435377
# 3PAr : 2.925930091600609
# TS% : 17.981742546968718
# TRB% : 0.3102717438847193
# AST% : -0.011662466341652869
# STL% : 0.7794427361103857
# BLK% : -0.14998171567779486

# %%
split_and_validate(X2,y)
# Out:
# Validation R^2 score was: 0.1685575135078281
# Feature coefficient results:
#
# Home : 6.39131348849189
# Away : -0.45289992783391003
# OeFG% : 70.5052825416935
# OTOV% : -0.6317633687245713
# ORB% : 0.20047181880593432
# OFT/FGA : 1.5226052092699904
# DeFG% : -21.39961890634945
# DTOV% : 0.9368376830878977
# DRB% : 0.3857366506355899
# DFT/FGA : -0.6953424327612345
