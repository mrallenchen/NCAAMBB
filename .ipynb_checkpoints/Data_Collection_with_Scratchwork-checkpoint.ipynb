# %%
from bs4 import BeautifulSoup
import requests
from IPython.core.display import display, HTML
import numpy as np
import re
import pickle
import pandas as pd
import re

# %% [markdown]
# ## Grab names for all NCAA teams

# %%
url = "https://www.sports-reference.com/cbb/schools/"
response = requests.get(url)
teams_text = response.text
team_soup = BeautifulSoup(teams_text, "lxml")
team_table = team_soup.find('table')
team_rows = team_table.find_all('tr')

# %%
#note that after every 20 teams, there is another header row
teams_list = {}
for i in [i for i in range(1,len(team_rows)) if i % 21 != 0]:
    items = team_rows[i].find_all('td')
    link = items[0].find('a')
    school, url = link.text, link['href']
    teams_list[school] = [url] + [i.text for i in items]

# %%
with open('teams_list.pickle', 'wb') as handle:
    pickle.dump(teams_list, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Create Dictionary of D1 Teams for each season

# %%
def teams(teams_list, season):
    '''
    Find teams in D1 for particular season
    
    input: season, this will be the year of interest
    output: a list of all the D1 teams that played that year, with their formal name
    '''
    season_teams = {}
    for team in teams_list.keys():
        if int(teams_list[team][3]) <= season <= int(teams_list[team][4]):
            season_teams[team] = teams_list[team]
    return season_teams

# %%
def team_name_dict(season_teams, season):
    '''
    Create team_lookup for names - url name as key, values include name, formal name, and team url
    
    input: the teams identified for a particular season, the year of the season
    output: a dictionary where the keys are the simple names 
    '''
    team_lookup = {}
    for key in season_teams:
        sched_url = "https://www.sports-reference.com" + season_teams[key][0] + str(season) +"-schedule.html"
        sched_response = requests.get(sched_url)
        sched_text = sched_response.text
        sched_soup = BeautifulSoup(sched_text,"lxml")
        sched_table = sched_soup.find('table')
        simple_name = re.split("\/",season_teams[key][0])[3]
        sched_rows = sched_table.find_all('tr')
        name = sched_table.find('a').text
        formal_name = season_teams[key][1]
        team_lookup[simple_name] = [name] + [formal_name] + [season_teams[key][0]]
    return team_lookup

# %%
#analysis was done for years 2014-2019, omitting 2020 because the season was cut short due to covid-19
for i in [2014, 2015, 2016, 2017, 2018, 2019]:
    season_teams = teams(teams_list, i)
    team_lookup = team_name_dict(season_teams, 2019)
    with open(f'team_lookup_{i}.pickle', 'wb') as handle:
        pickle.dump(team_lookup, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
team_lookup = pickle.load(open('team_lookup.pickle', "rb" ))

# %% [markdown]
# ## Helper functions to webscrap data

# %%
def grab_gamelog(season_teams, season):
    '''
    This grabs the gamelogs for all teams, for the season that is specified.
    
    Input: Dictionary where the keys are the teams for specified season; specified season
    Output: A dictionary, where each key stores a season's worth of individual game statistics for one team;
            The dictionary will hold all teams' information
    
    '''
    gamelog = {}
    for key in season_teams:
        game_url = "https://www.sports-reference.com" + season_teams[key][0] + str(season) +"-gamelogs.html"
        print(game_url)
        game_response = requests.get(game_url)
        gamelog_text = game_response.text
        gamelog_soup = BeautifulSoup(gamelog_text,"lxml")
        gamelog_table = gamelog_soup.find('table')
        gamelog_rows = gamelog_table.find_all('tr')
        team = re.split("\/",season_teams[key][0])[3]
        for i in [i for i in range(2,len(gamelog_rows)) if i % 22 != 0 and i % 23 != 0 and i % 44 != 0 and i % 45 != 0]:
            items = gamelog_rows[i].find_all('td')
            link = items[0].find('a')
            if link == None:
                pass
            else:
                date, url = link.text, link['href']
                gamelog[url + team] = [url] + [team] + [i.text for i in items]
    return gamelog

# %%
def grab_gamelog_advanced(season_teams, season):
    '''
    This grabs the gamelogs with ADVANCED STATS for all teams, for the season that is specified.
    
    Note this is exactly the same as the grab_gamelog function, except goes to a different website
    
    Input: Dictionary where the keys are the teams for specified season; specified season
    Output: A dictionary, where each key stores a season's worth of individual game statistics for one team;
            The dictionary will hold all teams' information
    
    '''
    gamelog = {}
    for key in season_teams:
        game_url = "https://www.sports-reference.com" + season_teams[key][0] + str(season) +"-gamelogs-advanced.html"
        game_response = requests.get(game_url)
        gamelog_text = game_response.text
        gamelog_soup = BeautifulSoup(gamelog_text,"lxml")
        gamelog_table = gamelog_soup.find('table')
        gamelog_rows = gamelog_table.find_all('tr')
        team = re.split("\/",season_teams[key][0])[3]
        for i in [i for i in range(2,len(gamelog_rows)) if i % 22 != 0 and i % 23 != 0 and i % 44 != 0 and i % 45 != 0]:
            items = gamelog_rows[i].find_all('td')
            link = items[0].find('a')
            if link == None:
                pass
            else:
                date, url = link.text, link['href']
                gamelog[url + team] = [url] + [team] + [i.text for i in items]
    return gamelog

# %%
def combine(gamelog, advanced_gamelog):
    '''
    Combines the two dictionaries so that there is a single dictionary housing both basic and advanced stats
    '''
    combo_log = {}
    for game in gamelog.keys():
        gamelog[game].extend(advanced_gamelog[game])
    return gamelog

# %% [markdown]
# ## Get Line Data

# %%
def get_line_data(year_nums):
    """
    Helper function to load data from http://www.thepredictiontracker.com/basketball.php
    """
    url = "http://www.thepredictiontracker.com/ncaabb{}.csv"
    dfs = []
    for year in year_nums:
        file_url = url.format(year-1)
        dfs.append(pd.read_csv(file_url))
    return pd.concat(dfs)

# %%
lines = get_line_data([14,15,16,17,18,19])
with open(f'lines.pickle', 'wb') as handle:
    pickle.dump(lines, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## CODE TO GRAB THE DATA

# %%
## Pull multiple seasons

my_seasons = [2015, 2019]

for i in my_seasons:
    this_season = teams(teams_list, i)
    
    this_gamelog = grab_gamelog(this_season, i)
    with open(f'gamelog_{i}.pickle', 'wb') as handle:
        pickle.dump(this_gamelog, handle, protocol=pickle.HIGHEST_PROTOCOL)
    print(f'gamelog {i}')        
        
    this_advanced_gamelog = grab_gamelog_advanced(this_season, i)
    with open(f'advanced_gamelog_{i}.pickle', 'wb') as handle:
        pickle.dump(this_advanced_gamelog, handle, protocol=pickle.HIGHEST_PROTOCOL)
    print(f'advanced_gamelog {i}')  
    
    this_combo_log = combine(this_gamelog, this_advanced_gamelog)
    with open(f'combo_log_{i}.pickle', 'wb') as handle:
        pickle.dump(this_combo_log, handle, protocol=pickle.HIGHEST_PROTOCOL)
    print(f'done with {i} season')
# Out:
# https://www.sports-reference.com/cbb/schools/abilene-christian/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/air-force/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/akron/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/alabama-am/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/alabama/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/alabama-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/alabama-birmingham/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/albany-ny/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/alcorn-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/american/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/appalachian-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/arizona-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/arizona/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/arkansas/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/arkansas-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/arkansas-pine-bluff/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/army/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/auburn/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/austin-peay/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/ball-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/baylor/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/belmont/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/bethune-cookman/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/binghamton/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/boise-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/boston-college/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/boston-university/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/bowling-green-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/bradley/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/brigham-young/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/brown/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/bryant/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/bucknell/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/buffalo/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/butler/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/cal-poly/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/cal-state-bakersfield/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/cal-state-fullerton/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/long-beach-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/cal-state-northridge/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/campbell/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/canisius/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/central-arkansas/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/central-connecticut-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/central-florida/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/central-michigan/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/charleston-southern/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/charlotte/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/chattanooga/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/chicago-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/cincinnati/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/citadel/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/clemson/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/cleveland-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/coastal-carolina/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/colgate/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/college-of-charleston/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/colorado/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/colorado-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/columbia/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/connecticut/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/coppin-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/cornell/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/creighton/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/dartmouth/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/davidson/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/dayton/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/delaware/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/delaware-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/denver/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/depaul/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/detroit-mercy/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/drake/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/drexel/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/duke/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/duquesne/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/east-carolina/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/east-tennessee-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/eastern-illinois/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/eastern-kentucky/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/eastern-michigan/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/eastern-washington/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/elon/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/evansville/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/fairfield/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/fairleigh-dickinson/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/florida-am/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/florida-atlantic/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/florida/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/florida-gulf-coast/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/florida-international/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/florida-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/fordham/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/fresno-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/furman/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/gardner-webb/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/george-mason/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/george-washington/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/georgetown/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/georgia/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/georgia-southern/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/georgia-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/georgia-tech/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/gonzaga/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/grambling/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/grand-canyon/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/green-bay/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/hampton/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/hartford/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/harvard/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/hawaii/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/high-point/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/hofstra/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/holy-cross/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/houston-baptist/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/houston/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/howard/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/idaho-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/idaho/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/illinois/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/illinois-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/illinois-chicago/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/incarnate-word/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/indiana/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/indiana-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/iona/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/iowa/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/iowa-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/iupui/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/jackson-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/jacksonville/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/jacksonville-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/james-madison/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/kansas/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/kansas-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/kennesaw-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/kent-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/kentucky/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/la-salle/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/lafayette/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/lamar/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/lehigh/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/liberty/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/lipscomb/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/arkansas-little-rock/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/long-island-university/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/longwood/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/louisiana-lafayette/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/louisiana-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/louisiana-tech/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/louisiana-monroe/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/louisville/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/loyola-il/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/loyola-md/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/loyola-marymount/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/maine/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/manhattan/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/marist/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/marquette/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/marshall/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/maryland/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/maryland-baltimore-county/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/maryland-eastern-shore/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/massachusetts/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/massachusetts-lowell/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/mcneese-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/memphis/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/mercer/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/miami-fl/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/miami-oh/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/michigan-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/michigan/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/middle-tennessee/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/milwaukee/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/minnesota/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/mississippi/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/mississippi-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/mississippi-valley-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/missouri-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/missouri/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/missouri-kansas-city/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/monmouth/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/montana/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/montana-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/morehead-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/morgan-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/mount-st-marys/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/murray-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/navy/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/nebraska/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/nevada/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/nevada-las-vegas/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/new-hampshire/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/new-mexico/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/new-mexico-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/new-orleans/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/niagara/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/nicholls-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/njit/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/norfolk-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/north-carolina-at/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/north-carolina-central/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/north-carolina-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/north-carolina/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/north-carolina-asheville/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/north-carolina-greensboro/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/north-carolina-wilmington/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/north-dakota/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/north-dakota-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/north-florida/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/north-texas/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/northeastern/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/northern-arizona/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/northern-colorado/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/northern-illinois/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/northern-iowa/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/northern-kentucky/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/northwestern-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/northwestern/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/notre-dame/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/oakland/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/ohio/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/ohio-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/oklahoma/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/oklahoma-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/old-dominion/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/nebraska-omaha/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/oral-roberts/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/oregon/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/oregon-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/pacific/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/penn-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/pennsylvania/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/pepperdine/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/pittsburgh/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/portland/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/portland-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/prairie-view/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/presbyterian/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/princeton/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/providence/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/purdue/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/ipfw/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/quinnipiac/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/radford/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/rhode-island/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/rice/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/richmond/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/rider/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/robert-morris/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/rutgers/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/sacramento-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/sacred-heart/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/saint-francis-pa/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/saint-josephs/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/saint-louis/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/saint-marys-ca/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/saint-peters/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/sam-houston-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/samford/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/san-diego-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/san-diego/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/san-francisco/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/san-jose-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/santa-clara/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/savannah-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/seattle/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/seton-hall/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/siena/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/south-alabama/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/south-carolina/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/south-carolina-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/south-carolina-upstate/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/south-dakota/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/south-dakota-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/south-florida/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/southeast-missouri-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/southeastern-louisiana/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/southern-california/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/southern-illinois/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/southern-illinois-edwardsville/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/southern/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/southern-methodist/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/southern-mississippi/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/southern-utah/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/st-bonaventure/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/st-francis-ny/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/st-johns-ny/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/stanford/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/stephen-f-austin/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/stetson/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/stony-brook/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/syracuse/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/temple/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/tennessee-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/tennessee-tech/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/tennessee/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/tennessee-martin/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/texas-am/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/texas-am-corpus-christi/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/texas-christian/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/texas/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/texas-southern/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/texas-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/texas-tech/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/texas-arlington/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/texas-el-paso/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/texas-pan-american/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/texas-san-antonio/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/toledo/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/towson/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/troy/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/tulane/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/tulsa/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/california-davis/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/california-irvine/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/california-riverside/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/california-santa-barbara/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/ucla/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/california/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/utah-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/utah/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/utah-valley/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/valparaiso/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/vanderbilt/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/vermont/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/villanova/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/virginia/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/virginia-commonwealth/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/virginia-military-institute/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/virginia-tech/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/wagner/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/wake-forest/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/washington/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/washington-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/weber-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/west-virginia/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/western-carolina/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/western-illinois/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/western-kentucky/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/western-michigan/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/wichita-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/william-mary/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/winthrop/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/wisconsin/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/wofford/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/wright-state/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/wyoming/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/xavier/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/yale/2015-gamelogs.html
# https://www.sports-reference.com/cbb/schools/youngstown-state/2015-gamelogs.html
# gamelog 2015
# advanced_gamelog 2015
# done with 2015 season
# https://www.sports-reference.com/cbb/schools/abilene-christian/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/air-force/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/akron/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/alabama-am/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/alabama/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/alabama-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/alabama-birmingham/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/albany-ny/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/alcorn-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/american/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/appalachian-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/arizona-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/arizona/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/arkansas/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/arkansas-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/arkansas-pine-bluff/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/army/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/auburn/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/austin-peay/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/ball-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/baylor/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/belmont/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/bethune-cookman/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/binghamton/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/boise-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/boston-college/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/boston-university/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/bowling-green-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/bradley/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/brigham-young/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/brown/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/bryant/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/bucknell/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/buffalo/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/butler/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/cal-poly/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/cal-state-bakersfield/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/cal-state-fullerton/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/long-beach-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/cal-state-northridge/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/california-baptist/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/campbell/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/canisius/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/central-arkansas/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/central-connecticut-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/central-florida/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/central-michigan/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/charleston-southern/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/charlotte/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/chattanooga/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/chicago-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/cincinnati/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/citadel/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/clemson/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/cleveland-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/coastal-carolina/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/colgate/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/college-of-charleston/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/colorado/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/colorado-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/columbia/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/connecticut/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/coppin-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/cornell/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/creighton/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/dartmouth/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/davidson/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/dayton/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/delaware/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/delaware-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/denver/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/depaul/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/detroit-mercy/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/drake/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/drexel/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/duke/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/duquesne/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/east-carolina/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/east-tennessee-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/eastern-illinois/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/eastern-kentucky/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/eastern-michigan/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/eastern-washington/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/elon/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/evansville/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/fairfield/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/fairleigh-dickinson/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/florida-am/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/florida-atlantic/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/florida/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/florida-gulf-coast/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/florida-international/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/florida-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/fordham/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/fresno-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/furman/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/gardner-webb/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/george-mason/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/george-washington/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/georgetown/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/georgia/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/georgia-southern/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/georgia-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/georgia-tech/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/gonzaga/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/grambling/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/grand-canyon/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/green-bay/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/hampton/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/hartford/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/harvard/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/hawaii/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/high-point/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/hofstra/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/holy-cross/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/houston-baptist/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/houston/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/howard/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/idaho-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/idaho/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/illinois/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/illinois-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/illinois-chicago/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/incarnate-word/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/indiana/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/indiana-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/iona/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/iowa/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/iowa-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/iupui/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/jackson-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/jacksonville/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/jacksonville-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/james-madison/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/kansas/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/kansas-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/kennesaw-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/kent-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/kentucky/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/la-salle/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/lafayette/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/lamar/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/lehigh/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/liberty/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/lipscomb/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/arkansas-little-rock/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/long-island-university/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/longwood/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/louisiana-lafayette/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/louisiana-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/louisiana-tech/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/louisiana-monroe/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/louisville/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/loyola-il/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/loyola-md/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/loyola-marymount/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/maine/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/manhattan/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/marist/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/marquette/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/marshall/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/maryland/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/maryland-baltimore-county/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/maryland-eastern-shore/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/massachusetts/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/massachusetts-lowell/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/mcneese-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/memphis/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/mercer/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/miami-fl/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/miami-oh/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/michigan-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/michigan/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/middle-tennessee/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/milwaukee/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/minnesota/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/mississippi/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/mississippi-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/mississippi-valley-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/missouri-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/missouri/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/missouri-kansas-city/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/monmouth/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/montana/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/montana-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/morehead-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/morgan-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/mount-st-marys/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/murray-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/navy/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/nebraska/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/nevada/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/nevada-las-vegas/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/new-hampshire/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/new-mexico/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/new-mexico-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/new-orleans/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/niagara/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/nicholls-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/njit/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/norfolk-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/north-alabama/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/north-carolina-at/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/north-carolina-central/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/north-carolina-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/north-carolina/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/north-carolina-asheville/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/north-carolina-greensboro/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/north-carolina-wilmington/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/north-dakota/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/north-dakota-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/north-florida/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/north-texas/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/northeastern/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/northern-arizona/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/northern-colorado/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/northern-illinois/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/northern-iowa/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/northern-kentucky/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/northwestern-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/northwestern/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/notre-dame/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/oakland/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/ohio/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/ohio-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/oklahoma/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/oklahoma-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/old-dominion/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/nebraska-omaha/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/oral-roberts/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/oregon/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/oregon-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/pacific/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/penn-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/pennsylvania/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/pepperdine/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/pittsburgh/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/portland/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/portland-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/prairie-view/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/presbyterian/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/princeton/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/providence/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/purdue/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/ipfw/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/quinnipiac/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/radford/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/rhode-island/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/rice/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/richmond/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/rider/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/robert-morris/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/rutgers/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/sacramento-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/sacred-heart/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/saint-francis-pa/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/saint-josephs/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/saint-louis/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/saint-marys-ca/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/saint-peters/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/sam-houston-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/samford/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/san-diego-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/san-diego/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/san-francisco/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/san-jose-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/santa-clara/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/savannah-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/seattle/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/seton-hall/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/siena/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/south-alabama/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/south-carolina/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/south-carolina-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/south-carolina-upstate/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/south-dakota/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/south-dakota-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/south-florida/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/southeast-missouri-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/southeastern-louisiana/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/southern-california/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/southern-illinois/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/southern-illinois-edwardsville/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/southern/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/southern-methodist/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/southern-mississippi/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/southern-utah/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/st-bonaventure/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/st-francis-ny/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/st-johns-ny/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/stanford/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/stephen-f-austin/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/stetson/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/stony-brook/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/syracuse/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/temple/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/tennessee-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/tennessee-tech/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/tennessee/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/tennessee-martin/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/texas-am/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/texas-am-corpus-christi/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/texas-christian/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/texas/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/texas-southern/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/texas-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/texas-tech/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/texas-arlington/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/texas-el-paso/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/texas-pan-american/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/texas-san-antonio/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/toledo/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/towson/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/troy/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/tulane/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/tulsa/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/california-davis/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/california-irvine/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/california-riverside/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/california-santa-barbara/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/ucla/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/california/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/utah-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/utah/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/utah-valley/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/valparaiso/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/vanderbilt/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/vermont/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/villanova/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/virginia/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/virginia-commonwealth/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/virginia-military-institute/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/virginia-tech/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/wagner/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/wake-forest/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/washington/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/washington-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/weber-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/west-virginia/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/western-carolina/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/western-illinois/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/western-kentucky/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/western-michigan/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/wichita-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/william-mary/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/winthrop/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/wisconsin/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/wofford/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/wright-state/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/wyoming/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/xavier/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/yale/2019-gamelogs.html
# https://www.sports-reference.com/cbb/schools/youngstown-state/2019-gamelogs.html
# gamelog 2019
# advanced_gamelog 2019
# done with 2019 season

# %% [markdown]
# ## Future work

# %% [markdown]
# ## Grab data from single game - hold off on pulling individual game data for now
#
# Input url for each game
# Output data table

# %%
def game_box_score(url)

# example url = 'https://www.sports-reference.com/cbb/boxscores/2020-03-11-21-stanford.html'
#note this will grab 8 tables (the last 4 will be basic and advanced stats, for each team)
    box = requests.get(url)
    boxscores = box.text
    soup = BeautifulSoup(boxscores, "html5lib")
    tables = soup.find_all('table')
    
    return tables

# %% [markdown]
# Pull Data from class "scorebox_meta": Date, Location <- this does not show up in a table
#
# Pull Data from table "line-score": <- this also does not show up in a table...
# Output: Away Team, Home Team, Away Score 1H, Away Score 2H, Away Score F, Home Score 1H, Home Score 2h, Home Score F
#
# ? What about overtimes...
#
# https://stackoverflow.com/questions/49766150/when-scraping-data-from-basketball-reference-how-come-certain-tables-are-comment

# %% [markdown]
# # Debugging - To delete

# %%
advanced_gamelog_2015 = grab_gamelog2(season15, 2015)
with open(f'advanced_gamelog_2015.pickle', 'wb') as handle:
    pickle.dump(advanced_gamelog_2015, handle, protocol=pickle.HIGHEST_PROTOCOL)
    print(f'advanced_gamelog {i}')

# %%
advanced_gamelog_2015

# %%
game_url = "https://www.sports-reference.com/cbb/schools/michigan/2018-gamelogs.html"
print(game_url)
game_response = requests.get(game_url)
gamelog_text = game_response.text
gamelog_soup = BeautifulSoup(gamelog_text,"lxml")
gamelog_table = gamelog_soup.find('table')
gamelog_rows = gamelog_table.find_all('tr')
team = "michigan"
# Out:
# https://www.sports-reference.com/cbb/schools/michigan/2018-gamelogs.html

# %%
gamelog = {}
for i in [i for i in range(2,len(gamelog_rows)) if i % 22 != 0 and i % 23 != 0 and i % 44 != 0 and i % 45 != 0]:
    items = gamelog_rows[i].find_all('td')
    link = items[0].find('a')
    if link == None:
        pass
    else:
        date, url = link.text, link['href']
        gamelog[url + team] = [url] + [team] + [i.text for i in items]

# %%
gamelog
# Out:
# {'/cbb/boxscores/2017-11-11-19-michigan.htmlmichigan': ['/cbb/boxscores/2017-11-11-19-michigan.html',
#   'michigan',
#   '2017-11-11',
#   '',
#   'North Florida',
#   'W',
#   '86',
#   '66',
#   '33',
#   '71',
#   '.465',
#   '9',
#   '25',
#   '.360',
#   '11',
#   '16',
#   '.688',
#   '12',
#   '35',
#   '21',
#   '12',
#   '2',
#   '10',
#   '12',
#   '',
#   '22',
#   '50',
#   '.440',
#   '9',
#   '15',
#   '.600',
#   '13',
#   '17',
#   '.765',
#   '6',
#   '28',
#   '11',
#   '5',
#   '4',
#   '23',
#   '19'],
#  '/cbb/boxscores/2017-11-13-19-michigan.htmlmichigan': ['/cbb/boxscores/2017-11-13-19-michigan.html',
#   'michigan',
#   '2017-11-13',
#   '',
#   'Central Michigan',
#   'W',
#   '72',
#   '65',
#   '26',
#   '59',
#   '.441',
#   '10',
#   '34',
#   '.294',
#   '10',
#   '12',
#   '.833',
#   '6',
#   '25',
#   '14',
#   '5',
#   '3',
#   '4',
#   '11',
#   '',
#   '22',
#   '51',
#   '.431',
#   '10',
#   '24',
#   '.417',
#   '11',
#   '12',
#   '.917',
#   '7',
#   '32',
#   '12',
#   '2',
#   '2',
#   '14',
#   '18'],
#  '/cbb/boxscores/2017-11-16-19-michigan.htmlmichigan': ['/cbb/boxscores/2017-11-16-19-michigan.html',
#   'michigan',
#   '2017-11-16',
#   '',
#   'Southern Miss',
#   'W',
#   '61',
#   '47',
#   '23',
#   '47',
#   '.489',
#   '8',
#   '23',
#   '.348',
#   '7',
#   '9',
#   '.778',
#   '8',
#   '31',
#   '13',
#   '5',
#   '3',
#   '9',
#   '10',
#   '',
#   '20',
#   '49',
#   '.408',
#   '6',
#   '13',
#   '.462',
#   '1',
#   '3',
#   '.333',
#   '5',
#   '22',
#   '9',
#   '4',
#   '0',
#   '10',
#   '12'],
#  '/cbb/boxscores/2017-11-20-23-louisiana-state.htmlmichigan': ['/cbb/boxscores/2017-11-20-23-louisiana-state.html',
#   'michigan',
#   '2017-11-20',
#   'N',
#   'LSU',
#   'L',
#   '75',
#   '77',
#   '27',
#   '59',
#   '.458',
#   '6',
#   '23',
#   '.261',
#   '15',
#   '21',
#   '.714',
#   '13',
#   '27',
#   '12',
#   '6',
#   '1',
#   '7',
#   '20',
#   '',
#   '27',
#   '46',
#   '.587',
#   '7',
#   '17',
#   '.412',
#   '16',
#   '23',
#   '.696',
#   '7',
#   '26',
#   '11',
#   '5',
#   '3',
#   '13',
#   '23'],
#  '/cbb/boxscores/2017-11-21-20-chaminade.htmlmichigan': ['/cbb/boxscores/2017-11-21-20-chaminade.html',
#   'michigan',
#   '2017-11-21',
#   'N',
#   'Chaminade',
#   'W',
#   '102',
#   '64',
#   '37',
#   '57',
#   '.649',
#   '15',
#   '28',
#   '.536',
#   '13',
#   '18',
#   '.722',
#   '6',
#   '32',
#   '22',
#   '9',
#   '6',
#   '8',
#   '12',
#   '',
#   '24',
#   '63',
#   '.381',
#   '5',
#   '22',
#   '.227',
#   '11',
#   '16',
#   '.688',
#   '15',
#   '30',
#   '9',
#   '3',
#   '0',
#   '13',
#   '17'],
#  '/cbb/boxscores/2017-11-22-17-michigan.htmlmichigan': ['/cbb/boxscores/2017-11-22-17-michigan.html',
#   'michigan',
#   '2017-11-22',
#   'N',
#   'VCU',
#   'W',
#   '68',
#   '60',
#   '25',
#   '53',
#   '.472',
#   '5',
#   '20',
#   '.250',
#   '13',
#   '22',
#   '.591',
#   '7',
#   '32',
#   '10',
#   '6',
#   '4',
#   '10',
#   '14',
#   '',
#   '25',
#   '56',
#   '.446',
#   '3',
#   '11',
#   '.273',
#   '7',
#   '11',
#   '.636',
#   '6',
#   '31',
#   '6',
#   '6',
#   '2',
#   '9',
#   '20'],
#  '/cbb/boxscores/2017-11-26-16-michigan.htmlmichigan': ['/cbb/boxscores/2017-11-26-16-michigan.html',
#   'michigan',
#   '2017-11-26',
#   '',
#   'UC-Riverside',
#   'W',
#   '87',
#   '42',
#   '34',
#   '63',
#   '.540',
#   '13',
#   '28',
#   '.464',
#   '6',
#   '11',
#   '.545',
#   '10',
#   '42',
#   '24',
#   '10',
#   '7',
#   '11',
#   '6',
#   '',
#   '18',
#   '60',
#   '.300',
#   '3',
#   '14',
#   '.214',
#   '3',
#   '6',
#   '.500',
#   '6',
#   '29',
#   '6',
#   '6',
#   '3',
#   '15',
#   '12'],
#  '/cbb/boxscores/2017-11-29-19-north-carolina.htmlmichigan': ['/cbb/boxscores/2017-11-29-19-north-carolina.html',
#   'michigan',
#   '2017-11-29',
#   '@',
#   'UNC',
#   'L',
#   '71',
#   '86',
#   '28',
#   '66',
#   '.424',
#   '10',
#   '34',
#   '.294',
#   '5',
#   '11',
#   '.455',
#   '9',
#   '27',
#   '16',
#   '8',
#   '6',
#   '10',
#   '16',
#   '',
#   '34',
#   '62',
#   '.548',
#   '7',
#   '15',
#   '.467',
#   '11',
#   '16',
#   '.688',
#   '9',
#   '34',
#   '24',
#   '2',
#   '6',
#   '12',
#   '12'],
#  '/cbb/boxscores/2017-12-02-12-michigan.htmlmichigan': ['/cbb/boxscores/2017-12-02-12-michigan.html',
#   'michigan',
#   '2017-12-02',
#   '',
#   'Indiana',
#   'W',
#   '69',
#   '55',
#   '26',
#   '55',
#   '.473',
#   '11',
#   '31',
#   '.355',
#   '6',
#   '10',
#   '.600',
#   '4',
#   '32',
#   '16',
#   '5',
#   '3',
#   '10',
#   '15',
#   '',
#   '22',
#   '55',
#   '.400',
#   '2',
#   '7',
#   '.286',
#   '9',
#   '14',
#   '.643',
#   '6',
#   '31',
#   '7',
#   '4',
#   '2',
#   '10',
#   '14'],
#  '/cbb/boxscores/2017-12-04-18-ohio-state.htmlmichigan': ['/cbb/boxscores/2017-12-04-18-ohio-state.html',
#   'michigan',
#   '2017-12-04',
#   '@',
#   'Ohio State',
#   'L',
#   '62',
#   '71',
#   '22',
#   '59',
#   '.373',
#   '8',
#   '28',
#   '.286',
#   '10',
#   '14',
#   '.714',
#   '11',
#   '31',
#   '13',
#   '5',
#   '0',
#   '8',
#   '20',
#   '',
#   '22',
#   '45',
#   '.489',
#   '5',
#   '14',
#   '.357',
#   '22',
#   '29',
#   '.759',
#   '5',
#   '32',
#   '12',
#   '4',
#   '4',
#   '10',
#   '18'],
#  '/cbb/boxscores/2017-12-09-12-michigan.htmlmichigan': ['/cbb/boxscores/2017-12-09-12-michigan.html',
#   'michigan',
#   '2017-12-09',
#   '',
#   'UCLA',
#   'W\xa0(1 OT)',
#   '78',
#   '69',
#   '30',
#   '64',
#   '.469',
#   '10',
#   '29',
#   '.345',
#   '8',
#   '22',
#   '.364',
#   '5',
#   '27',
#   '15',
#   '12',
#   '0',
#   '11',
#   '18',
#   '',
#   '25',
#   '57',
#   '.439',
#   '4',
#   '18',
#   '.222',
#   '15',
#   '21',
#   '.714',
#   '7',
#   '39',
#   '13',
#   '2',
#   '3',
#   '20',
#   '19'],
#  '/cbb/boxscores/2017-12-12-21-texas.htmlmichigan': ['/cbb/boxscores/2017-12-12-21-texas.html',
#   'michigan',
#   '2017-12-12',
#   '@',
#   'Texas',
#   'W',
#   '59',
#   '52',
#   '22',
#   '55',
#   '.400',
#   '6',
#   '19',
#   '.316',
#   '9',
#   '12',
#   '.750',
#   '9',
#   '38',
#   '9',
#   '3',
#   '3',
#   '10',
#   '17',
#   '',
#   '19',
#   '52',
#   '.365',
#   '5',
#   '20',
#   '.250',
#   '9',
#   '15',
#   '.600',
#   '4',
#   '27',
#   '6',
#   '5',
#   '4',
#   '10',
#   '17'],
#  '/cbb/boxscores/2017-12-16-12-detroit-mercy.htmlmichigan': ['/cbb/boxscores/2017-12-16-12-detroit-mercy.html',
#   'michigan',
#   '2017-12-16',
#   'N',
#   'Detroit',
#   'W',
#   '90',
#   '58',
#   '34',
#   '72',
#   '.472',
#   '11',
#   '23',
#   '.478',
#   '11',
#   '19',
#   '.579',
#   '13',
#   '41',
#   '19',
#   '11',
#   '5',
#   '9',
#   '18',
#   '',
#   '17',
#   '51',
#   '.333',
#   '5',
#   '16',
#   '.313',
#   '19',
#   '25',
#   '.760',
#   '7',
#   '35',
#   '6',
#   '4',
#   '3',
#   '23',
#   '20'],
#  '/cbb/boxscores/2017-12-21-21-michigan.htmlmichigan': ['/cbb/boxscores/2017-12-21-21-michigan.html',
#   'michigan',
#   '2017-12-21',
#   '',
#   'Alabama A&M',
#   'W',
#   '97',
#   '47',
#   '36',
#   '60',
#   '.600',
#   '15',
#   '32',
#   '.469',
#   '10',
#   '18',
#   '.556',
#   '5',
#   '31',
#   '23',
#   '10',
#   '5',
#   '12',
#   '16',
#   '',
#   '17',
#   '49',
#   '.347',
#   '4',
#   '17',
#   '.235',
#   '9',
#   '15',
#   '.600',
#   '7',
#   '28',
#   '8',
#   '4',
#   '1',
#   '23',
#   '18'],
#  '/cbb/boxscores/2017-12-30-18-michigan.htmlmichigan': ['/cbb/boxscores/2017-12-30-18-michigan.html',
#   'michigan',
#   '2017-12-30',
#   '',
#   'Jacksonville',
#   'W',
#   '76',
#   '51',
#   '31',
#   '55',
#   '.564',
#   '8',
#   '23',
#   '.348',
#   '6',
#   '9',
#   '.667',
#   '7',
#   '38',
#   '15',
#   '3',
#   '5',
#   '14',
#   '7',
#   '',
#   '20',
#   '59',
#   '.339',
#   '6',
#   '16',
#   '.375',
#   '5',
#   '7',
#   '.714',
#   '7',
#   '23',
#   '8',
#   '6',
#   '4',
#   '9',
#   '12'],
#  '/cbb/boxscores/2018-01-02-19-iowa.htmlmichigan': ['/cbb/boxscores/2018-01-02-19-iowa.html',
#   'michigan',
#   '2018-01-02',
#   '@',
#   'Iowa',
#   'W',
#   '75',
#   '68',
#   '28',
#   '57',
#   '.491',
#   '11',
#   '25',
#   '.440',
#   '8',
#   '10',
#   '.800',
#   '6',
#   '30',
#   '18',
#   '8',
#   '0',
#   '7',
#   '15',
#   '',
#   '25',
#   '52',
#   '.481',
#   '6',
#   '15',
#   '.400',
#   '12',
#   '17',
#   '.706',
#   '6',
#   '30',
#   '16',
#   '4',
#   '4',
#   '13',
#   '14'],
#  '/cbb/boxscores/2018-01-06-12-michigan.htmlmichigan': ['/cbb/boxscores/2018-01-06-12-michigan.html',
#   'michigan',
#   '2018-01-06',
#   '',
#   'Illinois',
#   'W',
#   '79',
#   '69',
#   '26',
#   '51',
#   '.510',
#   '8',
#   '20',
#   '.400',
#   '19',
#   '24',
#   '.792',
#   '5',
#   '24',
#   '18',
#   '7',
#   '5',
#   '15',
#   '17',
#   '',
#   '27',
#   '56',
#   '.482',
#   '3',
#   '14',
#   '.214',
#   '12',
#   '14',
#   '.857',
#   '9',
#   '30',
#   '13',
#   '7',
#   '4',
#   '17',
#   '22'],
#  '/cbb/boxscores/2018-01-09-21-michigan.htmlmichigan': ['/cbb/boxscores/2018-01-09-21-michigan.html',
#   'michigan',
#   '2018-01-09',
#   '',
#   'Purdue',
#   'L',
#   '69',
#   '70',
#   '26',
#   '58',
#   '.448',
#   '10',
#   '22',
#   '.455',
#   '7',
#   '11',
#   '.636',
#   '9',
#   '34',
#   '9',
#   '2',
#   '2',
#   '9',
#   '10',
#   '',
#   '27',
#   '57',
#   '.474',
#   '12',
#   '21',
#   '.571',
#   '4',
#   '7',
#   '.571',
#   '8',
#   '29',
#   '14',
#   '5',
#   '3',
#   '8',
#   '14'],
#  '/cbb/boxscores/2018-01-13-12-michigan-state.htmlmichigan': ['/cbb/boxscores/2018-01-13-12-michigan-state.html',
#   'michigan',
#   '2018-01-13',
#   '@',
#   'Michigan State',
#   'W',
#   '82',
#   '72',
#   '24',
#   '57',
#   '.421',
#   '6',
#   '15',
#   '.400',
#   '28',
#   '35',
#   '.800',
#   '8',
#   '27',
#   '13',
#   '6',
#   '4',
#   '7',
#   '25',
#   '',
#   '21',
#   '46',
#   '.457',
#   '3',
#   '13',
#   '.231',
#   '27',
#   '32',
#   '.844',
#   '8',
#   '32',
#   '13',
#   '3',
#   '8',
#   '17',
#   '26'],
#  '/cbb/boxscores/2018-01-15-18-michigan.htmlmichigan': ['/cbb/boxscores/2018-01-15-18-michigan.html',
#   'michigan',
#   '2018-01-15',
#   '',
#   'Maryland',
#   'W',
#   '68',
#   '67',
#   '25',
#   '61',
#   '.410',
#   '11',
#   '26',
#   '.423',
#   '7',
#   '12',
#   '.583',
#   '6',
#   '29',
#   '14',
#   '2',
#   '6',
#   '6',
#   '15',
#   '',
#   '25',
#   '52',
#   '.481',
#   '8',
#   '20',
#   '.400',
#   '9',
#   '14',
#   '.643',
#   '3',
#   '31',
#   '8',
#   '3',
#   '4',
#   '12',
#   '17'],
#  '/cbb/boxscores/2018-01-18-21-nebraska.htmlmichigan': ['/cbb/boxscores/2018-01-18-21-nebraska.html',
#   'michigan',
#   '2018-01-18',
#   '@',
#   'Nebraska',
#   'L',
#   '52',
#   '72',
#   '21',
#   '56',
#   '.375',
#   '4',
#   '18',
#   '.222',
#   '6',
#   '10',
#   '.600',
#   '14',
#   '32',
#   '6',
#   '4',
#   '2',
#   '12',
#   '19',
#   '',
#   '26',
#   '47',
#   '.553',
#   '5',
#   '11',
#   '.455',
#   '15',
#   '23',
#   '.652',
#   '7',
#   '28',
#   '12',
#   '9',
#   '4',
#   '9',
#   '14'],
#  '/cbb/boxscores/2018-01-21-12-michigan.htmlmichigan': ['/cbb/boxscores/2018-01-21-12-michigan.html',
#   'michigan',
#   '2018-01-21',
#   '',
#   'Rutgers',
#   'W',
#   '62',
#   '47',
#   '23',
#   '54',
#   '.426',
#   '8',
#   '25',
#   '.320',
#   '8',
#   '11',
#   '.727',
#   '5',
#   '31',
#   '16',
#   '4',
#   '2',
#   '9',
#   '15',
#   '',
#   '17',
#   '51',
#   '.333',
#   '2',
#   '9',
#   '.222',
#   '11',
#   '15',
#   '.733',
#   '7',
#   '31',
#   '1',
#   '4',
#   '1',
#   '13',
#   '18'],
#  '/cbb/boxscores/2018-01-25-19-purdue.htmlmichigan': ['/cbb/boxscores/2018-01-25-19-purdue.html',
#   'michigan',
#   '2018-01-25',
#   '@',
#   'Purdue',
#   'L',
#   '88',
#   '92',
#   '35',
#   '58',
#   '.603',
#   '13',
#   '23',
#   '.565',
#   '5',
#   '9',
#   '.556',
#   '7',
#   '21',
#   '14',
#   '5',
#   '3',
#   '11',
#   '20',
#   '',
#   '31',
#   '50',
#   '.620',
#   '11',
#   '20',
#   '.550',
#   '19',
#   '23',
#   '.826',
#   '4',
#   '18',
#   '22',
#   '7',
#   '6',
#   '10',
#   '11'],
#  '/cbb/boxscores/2018-01-29-19-michigan.htmlmichigan': ['/cbb/boxscores/2018-01-29-19-michigan.html',
#   'michigan',
#   '2018-01-29',
#   '',
#   'Northwestern',
#   'W',
#   '58',
#   '47',
#   '21',
#   '50',
#   '.420',
#   '7',
#   '25',
#   '.280',
#   '9',
#   '14',
#   '.643',
#   '4',
#   '28',
#   '13',
#   '8',
#   '1',
#   '5',
#   '13',
#   '',
#   '18',
#   '47',
#   '.383',
#   '4',
#   '16',
#   '.250',
#   '7',
#   '10',
#   '.700',
#   '5',
#   '31',
#   '7',
#   '2',
#   '1',
#   '16',
#   '20'],
#  '/cbb/boxscores/2018-02-03-14-michigan.htmlmichigan': ['/cbb/boxscores/2018-02-03-14-michigan.html',
#   'michigan',
#   '2018-02-03',
#   '',
#   'Minnesota',
#   'W\xa0(1 OT)',
#   '76',
#   '73',
#   '28',
#   '63',
#   '.444',
#   '8',
#   '32',
#   '.250',
#   '12',
#   '28',
#   '.429',
#   '10',
#   '39',
#   '12',
#   '1',
#   '2',
#   '6',
#   '16',
#   '',
#   '28',
#   '63',
#   '.444',
#   '5',
#   '18',
#   '.278',
#   '12',
#   '19',
#   '.632',
#   '4',
#   '30',
#   '6',
#   '2',
#   '2',
#   '5',
#   '20'],
#  '/cbb/boxscores/2018-02-06-19-northwestern.htmlmichigan': ['/cbb/boxscores/2018-02-06-19-northwestern.html',
#   'michigan',
#   '2018-02-06',
#   '@',
#   'Northwestern',
#   'L',
#   '52',
#   '61',
#   '17',
#   '44',
#   '.386',
#   '5',
#   '22',
#   '.227',
#   '13',
#   '19',
#   '.684',
#   '5',
#   '27',
#   '13',
#   '4',
#   '2',
#   '8',
#   '18',
#   '',
#   '20',
#   '50',
#   '.400',
#   '8',
#   '23',
#   '.348',
#   '13',
#   '17',
#   '.765',
#   '6',
#   '31',
#   '12',
#   '4',
#   '2',
#   '6',
#   '16'],
#  '/cbb/boxscores/2018-02-11-13-wisconsin.htmlmichigan': ['/cbb/boxscores/2018-02-11-13-wisconsin.html',
#   'michigan',
#   '2018-02-11',
#   '@',
#   'Wisconsin',
#   'W',
#   '83',
#   '72',
#   '28',
#   '50',
#   '.560',
#   '9',
#   '20',
#   '.450',
#   '18',
#   '24',
#   '.750',
#   '8',
#   '32',
#   '15',
#   '2',
#   '3',
#   '8',
#   '16',
#   '',
#   '27',
#   '55',
#   '.491',
#   '7',
#   '17',
#   '.412',
#   '11',
#   '14',
#   '.786',
#   '4',
#   '19',
#   '10',
#   '2',
#   '4',
#   '8',
#   '20'],
#  '/cbb/boxscores/2018-02-14-18-michigan.htmlmichigan': ['/cbb/boxscores/2018-02-14-18-michigan.html',
#   'michigan',
#   '2018-02-14',
#   '',
#   'Iowa',
#   'W',
#   '74',
#   '59',
#   '28',
#   '67',
#   '.418',
#   '12',
#   '33',
#   '.364',
#   '6',
#   '12',
#   '.500',
#   '10',
#   '31',
#   '19',
#   '13',
#   '2',
#   '5',
#   '13',
#   '',
#   '25',
#   '52',
#   '.481',
#   '2',
#   '10',
#   '.200',
#   '7',
#   '9',
#   '.778',
#   '5',
#   '33',
#   '15',
#   '3',
#   '3',
#   '15',
#   '15'],
#  '/cbb/boxscores/2018-02-18-13-michigan.htmlmichigan': ['/cbb/boxscores/2018-02-18-13-michigan.html',
#   'michigan',
#   '2018-02-18',
#   '',
#   'Ohio State',
#   'W',
#   '74',
#   '62',
#   '25',
#   '52',
#   '.481',
#   '7',
#   '20',
#   '.350',
#   '17',
#   '24',
#   '.708',
#   '2',
#   '27',
#   '12',
#   '6',
#   '2',
#   '6',
#   '17',
#   '',
#   '24',
#   '58',
#   '.414',
#   '5',
#   '11',
#   '.455',
#   '9',
#   '19',
#   '.474',
#   '13',
#   '37',
#   '8',
#   '5',
#   '5',
#   '14',
#   '22'],
#  '/cbb/boxscores/2018-02-21-19-penn-state.htmlmichigan': ['/cbb/boxscores/2018-02-21-19-penn-state.html',
#   'michigan',
#   '2018-02-21',
#   '@',
#   'Penn State',
#   'W',
#   '72',
#   '63',
#   '23',
#   '51',
#   '.451',
#   '10',
#   '21',
#   '.476',
#   '16',
#   '19',
#   '.842',
#   '5',
#   '32',
#   '15',
#   '8',
#   '6',
#   '11',
#   '15',
#   '',
#   '25',
#   '59',
#   '.424',
#   '7',
#   '18',
#   '.389',
#   '6',
#   '11',
#   '.545',
#   '4',
#   '26',
#   '10',
#   '6',
#   '6',
#   '10',
#   '19'],
#  '/cbb/boxscores/2018-02-24-12-maryland.htmlmichigan': ['/cbb/boxscores/2018-02-24-12-maryland.html',
#   'michigan',
#   '2018-02-24',
#   '@',
#   'Maryland',
#   'W',
#   '85',
#   '61',
#   '29',
#   '57',
#   '.509',
#   '15',
#   '31',
#   '.484',
#   '12',
#   '16',
#   '.750',
#   '8',
#   '29',
#   '18',
#   '6',
#   '5',
#   '8',
#   '18',
#   '',
#   '21',
#   '55',
#   '.382',
#   '3',
#   '18',
#   '.167',
#   '16',
#   '20',
#   '.800',
#   '9',
#   '30',
#   '10',
#   '3',
#   '1',
#   '11',
#   '14'],
#  '/cbb/boxscores/2018-03-01-14-michigan.htmlmichigan': ['/cbb/boxscores/2018-03-01-14-michigan.html',
#   'michigan',
#   '2018-03-01',
#   'N',
#   'Iowa',
#   'W\xa0(1 OT)',
#   '77',
#   '71',
#   '28',
#   '62',
#   '.452',
#   '3',
#   '19',
#   '.158',
#   '18',
#   '32',
#   '.563',
#   '10',
#   '41',
#   '11',
#   '8',
#   '2',
#   '7',
#   '22',
#   '',
#   '27',
#   '65',
#   '.415',
#   '7',
#   '23',
#   '.304',
#   '10',
#   '18',
#   '.556',
#   '8',
#   '37',
#   '17',
#   '2',
#   '1',
#   '14',
#   '24'],
#  '/cbb/boxscores/2018-03-02-14-nebraska.htmlmichigan': ['/cbb/boxscores/2018-03-02-14-nebraska.html',
#   'michigan',
#   '2018-03-02',
#   'N',
#   'Nebraska',
#   'W',
#   '77',
#   '58',
#   '27',
#   '61',
#   '.443',
#   '11',
#   '23',
#   '.478',
#   '12',
#   '15',
#   '.800',
#   '12',
#   '38',
#   '12',
#   '4',
#   '6',
#   '9',
#   '20',
#   '',
#   '16',
#   '53',
#   '.302',
#   '4',
#   '16',
#   '.250',
#   '22',
#   '27',
#   '.815',
#   '6',
#   '27',
#   '5',
#   '3',
#   '8',
#   '10',
#   '18'],
#  '/cbb/boxscores/2018-03-03-14-michigan-state.htmlmichigan': ['/cbb/boxscores/2018-03-03-14-michigan-state.html',
#   'michigan',
#   '2018-03-03',
#   'N',
#   'Michigan State',
#   'W',
#   '75',
#   '64',
#   '21',
#   '47',
#   '.447',
#   '9',
#   '25',
#   '.360',
#   '24',
#   '33',
#   '.727',
#   '4',
#   '34',
#   '10',
#   '5',
#   '1',
#   '8',
#   '13',
#   '',
#   '24',
#   '63',
#   '.381',
#   '7',
#   '25',
#   '.280',
#   '9',
#   '10',
#   '.900',
#   '9',
#   '32',
#   '10',
#   '4',
#   '1',
#   '8',
#   '23'],
#  '/cbb/boxscores/2018-03-04-16-purdue.htmlmichigan': ['/cbb/boxscores/2018-03-04-16-purdue.html',
#   'michigan',
#   '2018-03-04',
#   'N',
#   'Purdue',
#   'W',
#   '75',
#   '66',
#   '26',
#   '52',
#   '.500',
#   '8',
#   '23',
#   '.348',
#   '15',
#   '25',
#   '.600',
#   '4',
#   '23',
#   '18',
#   '6',
#   '2',
#   '5',
#   '16',
#   '',
#   '25',
#   '55',
#   '.455',
#   '4',
#   '17',
#   '.235',
#   '12',
#   '17',
#   '.706',
#   '7',
#   '35',
#   '8',
#   '2',
#   '1',
#   '11',
#   '21'],
#  '/cbb/boxscores/2018-03-15-21-michigan.htmlmichigan': ['/cbb/boxscores/2018-03-15-21-michigan.html',
#   'michigan',
#   '2018-03-15',
#   'N',
#   'Montana',
#   'W',
#   '61',
#   '47',
#   '21',
#   '47',
#   '.447',
#   '5',
#   '16',
#   '.313',
#   '14',
#   '22',
#   '.636',
#   '5',
#   '35',
#   '11',
#   '4',
#   '3',
#   '13',
#   '14',
#   '',
#   '18',
#   '56',
#   '.321',
#   '3',
#   '15',
#   '.200',
#   '8',
#   '11',
#   '.727',
#   '8',
#   '33',
#   '7',
#   '7',
#   '2',
#   '12',
#   '21'],
#  '/cbb/boxscores/2018-03-17-21-michigan.htmlmichigan': ['/cbb/boxscores/2018-03-17-21-michigan.html',
#   'michigan',
#   '2018-03-17',
#   'N',
#   'Houston',
#   'W',
#   '64',
#   '63',
#   '21',
#   '59',
#   '.356',
#   '8',
#   '30',
#   '.267',
#   '14',
#   '20',
#   '.700',
#   '7',
#   '33',
#   '13',
#   '4',
#   '5',
#   '7',
#   '22',
#   '',
#   '20',
#   '54',
#   '.370',
#   '7',
#   '18',
#   '.389',
#   '16',
#   '22',
#   '.727',
#   '8',
#   '37',
#   '8',
#   '3',
#   '2',
#   '10',
#   '19'],
#  '/cbb/boxscores/2018-03-22-19-michigan.htmlmichigan': ['/cbb/boxscores/2018-03-22-19-michigan.html',
#   'michigan',
#   '2018-03-22',
#   'N',
#   'Texas A&M',
#   'W',
#   '99',
#   '72',
#   '39',
#   '63',
#   '.619',
#   '14',
#   '24',
#   '.583',
#   '7',
#   '8',
#   '.875',
#   '2',
#   '26',
#   '21',
#   '12',
#   '0',
#   '6',
#   '15',
#   '',
#   '32',
#   '67',
#   '.478',
#   '3',
#   '15',
#   '.200',
#   '5',
#   '10',
#   '.500',
#   '11',
#   '31',
#   '13',
#   '4',
#   '4',
#   '14',
#   '12'],
#  '/cbb/boxscores/2018-03-24-20-michigan.htmlmichigan': ['/cbb/boxscores/2018-03-24-20-michigan.html',
#   'michigan',
#   '2018-03-24',
#   'N',
#   'Florida State',
#   'W',
#   '58',
#   '54',
#   '19',
#   '49',
#   '.388',
#   '4',
#   '22',
#   '.182',
#   '16',
#   '24',
#   '.667',
#   '7',
#   '30',
#   '8',
#   '6',
#   '4',
#   '10',
#   '16',
#   '',
#   '16',
#   '51',
#   '.314',
#   '4',
#   '17',
#   '.235',
#   '18',
#   '20',
#   '.900',
#   '10',
#   '33',
#   '6',
#   '6',
#   '7',
#   '13',
#   '23'],
#  '/cbb/boxscores/2018-03-31-18-michigan.htmlmichigan': ['/cbb/boxscores/2018-03-31-18-michigan.html',
#   'michigan',
#   '2018-03-31',
#   'N',
#   'Loyola (IL)',
#   'W',
#   '69',
#   '57',
#   '25',
#   '59',
#   '.424',
#   '7',
#   '28',
#   '.250',
#   '12',
#   '18',
#   '.667',
#   '10',
#   '35',
#   '8',
#   '10',
#   '2',
#   '11',
#   '11',
#   '',
#   '22',
#   '51',
#   '.431',
#   '1',
#   '10',
#   '.100',
#   '12',
#   '14',
#   '.857',
#   '5',
#   '31',
#   '6',
#   '5',
#   '1',
#   '17',
#   '17']}

# %%
gamelog_rows[46]
# Out:
# <tr id="sgl-basic.20180402"><th class="right" data-stat="game_season" scope="row">41</th><td class="left" data-stat="date_game"><a href="/cbb/boxscores/2018-04-02-21-villanova.html">2018-04-02</a></td><td class="left" data-stat="game_location">N</td><td class="left" data-stat="opp_id"><a href="/cbb/schools/villanova/2018.html">Villanova</a></td><td class="left" csk="2" data-stat="game_result">L</td><td class="right" data-stat="pts">62</td><td class="right" data-stat="opp_pts">79</td><td class="right" data-stat="fg">24</td><td class="right" data-stat="fga">55</td><td class="right" data-stat="fg_pct">.436</td><td class="right" data-stat="fg3">3</td><td class="right" data-stat="fg3a">23</td><td class="right" data-stat="fg3_pct">.130</td><td class="right" data-stat="ft">11</td><td class="right" data-stat="fta">18</td><td class="right" data-stat="ft_pct">.611</td><td class="right" data-stat="orb">5</td><td class="right" data-stat="trb">26</td><td class="right" data-stat="ast">6</td><td class="right" data-stat="stl">6</td><td class="right" data-stat="blk">1</td><td class="right" data-stat="tov">10</td><td class="right" data-stat="pf">20</td><td class="right iz" data-stat="x"></td><td class="right" data-stat="opp_fg">27</td><td class="right" data-stat="opp_fga">57</td><td class="right" data-stat="opp_fg_pct">.474</td><td class="right" data-stat="opp_fg3">10</td><td class="right" data-stat="opp_fg3a">27</td><td class="right" data-stat="opp_fg3_pct">.370</td><td class="right" data-stat="opp_ft">15</td><td class="right" data-stat="opp_fta">20</td><td class="right" data-stat="opp_ft_pct">.750</td><td class="right" data-stat="opp_orb">12</td><td class="right" data-stat="opp_trb">38</td><td class="right" data-stat="opp_ast">7</td><td class="right" data-stat="opp_stl">5</td><td class="right" data-stat="opp_blk">3</td><td class="right" data-stat="opp_tov">12</td><td class="right" data-stat="opp_pf">18</td></tr>

# %%
items = gamelog_rows[46].find_all('td')
link = items[0].find('a')
if link == None:
    pass
else:
    date, url = link.text, link['href']
    gamelog[url + team] = [url] + [team] + [i.text for i in items]

# %%
gamelog
# Out:
# {'/cbb/boxscores/2017-11-11-19-michigan.htmlmichigan': ['/cbb/boxscores/2017-11-11-19-michigan.html',
#   'michigan',
#   '2017-11-11',
#   '',
#   'North Florida',
#   'W',
#   '86',
#   '66',
#   '33',
#   '71',
#   '.465',
#   '9',
#   '25',
#   '.360',
#   '11',
#   '16',
#   '.688',
#   '12',
#   '35',
#   '21',
#   '12',
#   '2',
#   '10',
#   '12',
#   '',
#   '22',
#   '50',
#   '.440',
#   '9',
#   '15',
#   '.600',
#   '13',
#   '17',
#   '.765',
#   '6',
#   '28',
#   '11',
#   '5',
#   '4',
#   '23',
#   '19'],
#  '/cbb/boxscores/2017-11-13-19-michigan.htmlmichigan': ['/cbb/boxscores/2017-11-13-19-michigan.html',
#   'michigan',
#   '2017-11-13',
#   '',
#   'Central Michigan',
#   'W',
#   '72',
#   '65',
#   '26',
#   '59',
#   '.441',
#   '10',
#   '34',
#   '.294',
#   '10',
#   '12',
#   '.833',
#   '6',
#   '25',
#   '14',
#   '5',
#   '3',
#   '4',
#   '11',
#   '',
#   '22',
#   '51',
#   '.431',
#   '10',
#   '24',
#   '.417',
#   '11',
#   '12',
#   '.917',
#   '7',
#   '32',
#   '12',
#   '2',
#   '2',
#   '14',
#   '18'],
#  '/cbb/boxscores/2017-11-16-19-michigan.htmlmichigan': ['/cbb/boxscores/2017-11-16-19-michigan.html',
#   'michigan',
#   '2017-11-16',
#   '',
#   'Southern Miss',
#   'W',
#   '61',
#   '47',
#   '23',
#   '47',
#   '.489',
#   '8',
#   '23',
#   '.348',
#   '7',
#   '9',
#   '.778',
#   '8',
#   '31',
#   '13',
#   '5',
#   '3',
#   '9',
#   '10',
#   '',
#   '20',
#   '49',
#   '.408',
#   '6',
#   '13',
#   '.462',
#   '1',
#   '3',
#   '.333',
#   '5',
#   '22',
#   '9',
#   '4',
#   '0',
#   '10',
#   '12'],
#  '/cbb/boxscores/2017-11-20-23-louisiana-state.htmlmichigan': ['/cbb/boxscores/2017-11-20-23-louisiana-state.html',
#   'michigan',
#   '2017-11-20',
#   'N',
#   'LSU',
#   'L',
#   '75',
#   '77',
#   '27',
#   '59',
#   '.458',
#   '6',
#   '23',
#   '.261',
#   '15',
#   '21',
#   '.714',
#   '13',
#   '27',
#   '12',
#   '6',
#   '1',
#   '7',
#   '20',
#   '',
#   '27',
#   '46',
#   '.587',
#   '7',
#   '17',
#   '.412',
#   '16',
#   '23',
#   '.696',
#   '7',
#   '26',
#   '11',
#   '5',
#   '3',
#   '13',
#   '23'],
#  '/cbb/boxscores/2017-11-21-20-chaminade.htmlmichigan': ['/cbb/boxscores/2017-11-21-20-chaminade.html',
#   'michigan',
#   '2017-11-21',
#   'N',
#   'Chaminade',
#   'W',
#   '102',
#   '64',
#   '37',
#   '57',
#   '.649',
#   '15',
#   '28',
#   '.536',
#   '13',
#   '18',
#   '.722',
#   '6',
#   '32',
#   '22',
#   '9',
#   '6',
#   '8',
#   '12',
#   '',
#   '24',
#   '63',
#   '.381',
#   '5',
#   '22',
#   '.227',
#   '11',
#   '16',
#   '.688',
#   '15',
#   '30',
#   '9',
#   '3',
#   '0',
#   '13',
#   '17'],
#  '/cbb/boxscores/2017-11-22-17-michigan.htmlmichigan': ['/cbb/boxscores/2017-11-22-17-michigan.html',
#   'michigan',
#   '2017-11-22',
#   'N',
#   'VCU',
#   'W',
#   '68',
#   '60',
#   '25',
#   '53',
#   '.472',
#   '5',
#   '20',
#   '.250',
#   '13',
#   '22',
#   '.591',
#   '7',
#   '32',
#   '10',
#   '6',
#   '4',
#   '10',
#   '14',
#   '',
#   '25',
#   '56',
#   '.446',
#   '3',
#   '11',
#   '.273',
#   '7',
#   '11',
#   '.636',
#   '6',
#   '31',
#   '6',
#   '6',
#   '2',
#   '9',
#   '20'],
#  '/cbb/boxscores/2017-11-26-16-michigan.htmlmichigan': ['/cbb/boxscores/2017-11-26-16-michigan.html',
#   'michigan',
#   '2017-11-26',
#   '',
#   'UC-Riverside',
#   'W',
#   '87',
#   '42',
#   '34',
#   '63',
#   '.540',
#   '13',
#   '28',
#   '.464',
#   '6',
#   '11',
#   '.545',
#   '10',
#   '42',
#   '24',
#   '10',
#   '7',
#   '11',
#   '6',
#   '',
#   '18',
#   '60',
#   '.300',
#   '3',
#   '14',
#   '.214',
#   '3',
#   '6',
#   '.500',
#   '6',
#   '29',
#   '6',
#   '6',
#   '3',
#   '15',
#   '12'],
#  '/cbb/boxscores/2017-11-29-19-north-carolina.htmlmichigan': ['/cbb/boxscores/2017-11-29-19-north-carolina.html',
#   'michigan',
#   '2017-11-29',
#   '@',
#   'UNC',
#   'L',
#   '71',
#   '86',
#   '28',
#   '66',
#   '.424',
#   '10',
#   '34',
#   '.294',
#   '5',
#   '11',
#   '.455',
#   '9',
#   '27',
#   '16',
#   '8',
#   '6',
#   '10',
#   '16',
#   '',
#   '34',
#   '62',
#   '.548',
#   '7',
#   '15',
#   '.467',
#   '11',
#   '16',
#   '.688',
#   '9',
#   '34',
#   '24',
#   '2',
#   '6',
#   '12',
#   '12'],
#  '/cbb/boxscores/2017-12-02-12-michigan.htmlmichigan': ['/cbb/boxscores/2017-12-02-12-michigan.html',
#   'michigan',
#   '2017-12-02',
#   '',
#   'Indiana',
#   'W',
#   '69',
#   '55',
#   '26',
#   '55',
#   '.473',
#   '11',
#   '31',
#   '.355',
#   '6',
#   '10',
#   '.600',
#   '4',
#   '32',
#   '16',
#   '5',
#   '3',
#   '10',
#   '15',
#   '',
#   '22',
#   '55',
#   '.400',
#   '2',
#   '7',
#   '.286',
#   '9',
#   '14',
#   '.643',
#   '6',
#   '31',
#   '7',
#   '4',
#   '2',
#   '10',
#   '14'],
#  '/cbb/boxscores/2017-12-04-18-ohio-state.htmlmichigan': ['/cbb/boxscores/2017-12-04-18-ohio-state.html',
#   'michigan',
#   '2017-12-04',
#   '@',
#   'Ohio State',
#   'L',
#   '62',
#   '71',
#   '22',
#   '59',
#   '.373',
#   '8',
#   '28',
#   '.286',
#   '10',
#   '14',
#   '.714',
#   '11',
#   '31',
#   '13',
#   '5',
#   '0',
#   '8',
#   '20',
#   '',
#   '22',
#   '45',
#   '.489',
#   '5',
#   '14',
#   '.357',
#   '22',
#   '29',
#   '.759',
#   '5',
#   '32',
#   '12',
#   '4',
#   '4',
#   '10',
#   '18'],
#  '/cbb/boxscores/2017-12-09-12-michigan.htmlmichigan': ['/cbb/boxscores/2017-12-09-12-michigan.html',
#   'michigan',
#   '2017-12-09',
#   '',
#   'UCLA',
#   'W\xa0(1 OT)',
#   '78',
#   '69',
#   '30',
#   '64',
#   '.469',
#   '10',
#   '29',
#   '.345',
#   '8',
#   '22',
#   '.364',
#   '5',
#   '27',
#   '15',
#   '12',
#   '0',
#   '11',
#   '18',
#   '',
#   '25',
#   '57',
#   '.439',
#   '4',
#   '18',
#   '.222',
#   '15',
#   '21',
#   '.714',
#   '7',
#   '39',
#   '13',
#   '2',
#   '3',
#   '20',
#   '19'],
#  '/cbb/boxscores/2017-12-12-21-texas.htmlmichigan': ['/cbb/boxscores/2017-12-12-21-texas.html',
#   'michigan',
#   '2017-12-12',
#   '@',
#   'Texas',
#   'W',
#   '59',
#   '52',
#   '22',
#   '55',
#   '.400',
#   '6',
#   '19',
#   '.316',
#   '9',
#   '12',
#   '.750',
#   '9',
#   '38',
#   '9',
#   '3',
#   '3',
#   '10',
#   '17',
#   '',
#   '19',
#   '52',
#   '.365',
#   '5',
#   '20',
#   '.250',
#   '9',
#   '15',
#   '.600',
#   '4',
#   '27',
#   '6',
#   '5',
#   '4',
#   '10',
#   '17'],
#  '/cbb/boxscores/2017-12-16-12-detroit-mercy.htmlmichigan': ['/cbb/boxscores/2017-12-16-12-detroit-mercy.html',
#   'michigan',
#   '2017-12-16',
#   'N',
#   'Detroit',
#   'W',
#   '90',
#   '58',
#   '34',
#   '72',
#   '.472',
#   '11',
#   '23',
#   '.478',
#   '11',
#   '19',
#   '.579',
#   '13',
#   '41',
#   '19',
#   '11',
#   '5',
#   '9',
#   '18',
#   '',
#   '17',
#   '51',
#   '.333',
#   '5',
#   '16',
#   '.313',
#   '19',
#   '25',
#   '.760',
#   '7',
#   '35',
#   '6',
#   '4',
#   '3',
#   '23',
#   '20'],
#  '/cbb/boxscores/2017-12-21-21-michigan.htmlmichigan': ['/cbb/boxscores/2017-12-21-21-michigan.html',
#   'michigan',
#   '2017-12-21',
#   '',
#   'Alabama A&M',
#   'W',
#   '97',
#   '47',
#   '36',
#   '60',
#   '.600',
#   '15',
#   '32',
#   '.469',
#   '10',
#   '18',
#   '.556',
#   '5',
#   '31',
#   '23',
#   '10',
#   '5',
#   '12',
#   '16',
#   '',
#   '17',
#   '49',
#   '.347',
#   '4',
#   '17',
#   '.235',
#   '9',
#   '15',
#   '.600',
#   '7',
#   '28',
#   '8',
#   '4',
#   '1',
#   '23',
#   '18'],
#  '/cbb/boxscores/2017-12-30-18-michigan.htmlmichigan': ['/cbb/boxscores/2017-12-30-18-michigan.html',
#   'michigan',
#   '2017-12-30',
#   '',
#   'Jacksonville',
#   'W',
#   '76',
#   '51',
#   '31',
#   '55',
#   '.564',
#   '8',
#   '23',
#   '.348',
#   '6',
#   '9',
#   '.667',
#   '7',
#   '38',
#   '15',
#   '3',
#   '5',
#   '14',
#   '7',
#   '',
#   '20',
#   '59',
#   '.339',
#   '6',
#   '16',
#   '.375',
#   '5',
#   '7',
#   '.714',
#   '7',
#   '23',
#   '8',
#   '6',
#   '4',
#   '9',
#   '12'],
#  '/cbb/boxscores/2018-01-02-19-iowa.htmlmichigan': ['/cbb/boxscores/2018-01-02-19-iowa.html',
#   'michigan',
#   '2018-01-02',
#   '@',
#   'Iowa',
#   'W',
#   '75',
#   '68',
#   '28',
#   '57',
#   '.491',
#   '11',
#   '25',
#   '.440',
#   '8',
#   '10',
#   '.800',
#   '6',
#   '30',
#   '18',
#   '8',
#   '0',
#   '7',
#   '15',
#   '',
#   '25',
#   '52',
#   '.481',
#   '6',
#   '15',
#   '.400',
#   '12',
#   '17',
#   '.706',
#   '6',
#   '30',
#   '16',
#   '4',
#   '4',
#   '13',
#   '14'],
#  '/cbb/boxscores/2018-01-06-12-michigan.htmlmichigan': ['/cbb/boxscores/2018-01-06-12-michigan.html',
#   'michigan',
#   '2018-01-06',
#   '',
#   'Illinois',
#   'W',
#   '79',
#   '69',
#   '26',
#   '51',
#   '.510',
#   '8',
#   '20',
#   '.400',
#   '19',
#   '24',
#   '.792',
#   '5',
#   '24',
#   '18',
#   '7',
#   '5',
#   '15',
#   '17',
#   '',
#   '27',
#   '56',
#   '.482',
#   '3',
#   '14',
#   '.214',
#   '12',
#   '14',
#   '.857',
#   '9',
#   '30',
#   '13',
#   '7',
#   '4',
#   '17',
#   '22'],
#  '/cbb/boxscores/2018-01-09-21-michigan.htmlmichigan': ['/cbb/boxscores/2018-01-09-21-michigan.html',
#   'michigan',
#   '2018-01-09',
#   '',
#   'Purdue',
#   'L',
#   '69',
#   '70',
#   '26',
#   '58',
#   '.448',
#   '10',
#   '22',
#   '.455',
#   '7',
#   '11',
#   '.636',
#   '9',
#   '34',
#   '9',
#   '2',
#   '2',
#   '9',
#   '10',
#   '',
#   '27',
#   '57',
#   '.474',
#   '12',
#   '21',
#   '.571',
#   '4',
#   '7',
#   '.571',
#   '8',
#   '29',
#   '14',
#   '5',
#   '3',
#   '8',
#   '14'],
#  '/cbb/boxscores/2018-01-13-12-michigan-state.htmlmichigan': ['/cbb/boxscores/2018-01-13-12-michigan-state.html',
#   'michigan',
#   '2018-01-13',
#   '@',
#   'Michigan State',
#   'W',
#   '82',
#   '72',
#   '24',
#   '57',
#   '.421',
#   '6',
#   '15',
#   '.400',
#   '28',
#   '35',
#   '.800',
#   '8',
#   '27',
#   '13',
#   '6',
#   '4',
#   '7',
#   '25',
#   '',
#   '21',
#   '46',
#   '.457',
#   '3',
#   '13',
#   '.231',
#   '27',
#   '32',
#   '.844',
#   '8',
#   '32',
#   '13',
#   '3',
#   '8',
#   '17',
#   '26'],
#  '/cbb/boxscores/2018-01-15-18-michigan.htmlmichigan': ['/cbb/boxscores/2018-01-15-18-michigan.html',
#   'michigan',
#   '2018-01-15',
#   '',
#   'Maryland',
#   'W',
#   '68',
#   '67',
#   '25',
#   '61',
#   '.410',
#   '11',
#   '26',
#   '.423',
#   '7',
#   '12',
#   '.583',
#   '6',
#   '29',
#   '14',
#   '2',
#   '6',
#   '6',
#   '15',
#   '',
#   '25',
#   '52',
#   '.481',
#   '8',
#   '20',
#   '.400',
#   '9',
#   '14',
#   '.643',
#   '3',
#   '31',
#   '8',
#   '3',
#   '4',
#   '12',
#   '17'],
#  '/cbb/boxscores/2018-01-18-21-nebraska.htmlmichigan': ['/cbb/boxscores/2018-01-18-21-nebraska.html',
#   'michigan',
#   '2018-01-18',
#   '@',
#   'Nebraska',
#   'L',
#   '52',
#   '72',
#   '21',
#   '56',
#   '.375',
#   '4',
#   '18',
#   '.222',
#   '6',
#   '10',
#   '.600',
#   '14',
#   '32',
#   '6',
#   '4',
#   '2',
#   '12',
#   '19',
#   '',
#   '26',
#   '47',
#   '.553',
#   '5',
#   '11',
#   '.455',
#   '15',
#   '23',
#   '.652',
#   '7',
#   '28',
#   '12',
#   '9',
#   '4',
#   '9',
#   '14'],
#  '/cbb/boxscores/2018-01-21-12-michigan.htmlmichigan': ['/cbb/boxscores/2018-01-21-12-michigan.html',
#   'michigan',
#   '2018-01-21',
#   '',
#   'Rutgers',
#   'W',
#   '62',
#   '47',
#   '23',
#   '54',
#   '.426',
#   '8',
#   '25',
#   '.320',
#   '8',
#   '11',
#   '.727',
#   '5',
#   '31',
#   '16',
#   '4',
#   '2',
#   '9',
#   '15',
#   '',
#   '17',
#   '51',
#   '.333',
#   '2',
#   '9',
#   '.222',
#   '11',
#   '15',
#   '.733',
#   '7',
#   '31',
#   '1',
#   '4',
#   '1',
#   '13',
#   '18'],
#  '/cbb/boxscores/2018-01-25-19-purdue.htmlmichigan': ['/cbb/boxscores/2018-01-25-19-purdue.html',
#   'michigan',
#   '2018-01-25',
#   '@',
#   'Purdue',
#   'L',
#   '88',
#   '92',
#   '35',
#   '58',
#   '.603',
#   '13',
#   '23',
#   '.565',
#   '5',
#   '9',
#   '.556',
#   '7',
#   '21',
#   '14',
#   '5',
#   '3',
#   '11',
#   '20',
#   '',
#   '31',
#   '50',
#   '.620',
#   '11',
#   '20',
#   '.550',
#   '19',
#   '23',
#   '.826',
#   '4',
#   '18',
#   '22',
#   '7',
#   '6',
#   '10',
#   '11'],
#  '/cbb/boxscores/2018-01-29-19-michigan.htmlmichigan': ['/cbb/boxscores/2018-01-29-19-michigan.html',
#   'michigan',
#   '2018-01-29',
#   '',
#   'Northwestern',
#   'W',
#   '58',
#   '47',
#   '21',
#   '50',
#   '.420',
#   '7',
#   '25',
#   '.280',
#   '9',
#   '14',
#   '.643',
#   '4',
#   '28',
#   '13',
#   '8',
#   '1',
#   '5',
#   '13',
#   '',
#   '18',
#   '47',
#   '.383',
#   '4',
#   '16',
#   '.250',
#   '7',
#   '10',
#   '.700',
#   '5',
#   '31',
#   '7',
#   '2',
#   '1',
#   '16',
#   '20'],
#  '/cbb/boxscores/2018-02-03-14-michigan.htmlmichigan': ['/cbb/boxscores/2018-02-03-14-michigan.html',
#   'michigan',
#   '2018-02-03',
#   '',
#   'Minnesota',
#   'W\xa0(1 OT)',
#   '76',
#   '73',
#   '28',
#   '63',
#   '.444',
#   '8',
#   '32',
#   '.250',
#   '12',
#   '28',
#   '.429',
#   '10',
#   '39',
#   '12',
#   '1',
#   '2',
#   '6',
#   '16',
#   '',
#   '28',
#   '63',
#   '.444',
#   '5',
#   '18',
#   '.278',
#   '12',
#   '19',
#   '.632',
#   '4',
#   '30',
#   '6',
#   '2',
#   '2',
#   '5',
#   '20'],
#  '/cbb/boxscores/2018-02-06-19-northwestern.htmlmichigan': ['/cbb/boxscores/2018-02-06-19-northwestern.html',
#   'michigan',
#   '2018-02-06',
#   '@',
#   'Northwestern',
#   'L',
#   '52',
#   '61',
#   '17',
#   '44',
#   '.386',
#   '5',
#   '22',
#   '.227',
#   '13',
#   '19',
#   '.684',
#   '5',
#   '27',
#   '13',
#   '4',
#   '2',
#   '8',
#   '18',
#   '',
#   '20',
#   '50',
#   '.400',
#   '8',
#   '23',
#   '.348',
#   '13',
#   '17',
#   '.765',
#   '6',
#   '31',
#   '12',
#   '4',
#   '2',
#   '6',
#   '16'],
#  '/cbb/boxscores/2018-02-11-13-wisconsin.htmlmichigan': ['/cbb/boxscores/2018-02-11-13-wisconsin.html',
#   'michigan',
#   '2018-02-11',
#   '@',
#   'Wisconsin',
#   'W',
#   '83',
#   '72',
#   '28',
#   '50',
#   '.560',
#   '9',
#   '20',
#   '.450',
#   '18',
#   '24',
#   '.750',
#   '8',
#   '32',
#   '15',
#   '2',
#   '3',
#   '8',
#   '16',
#   '',
#   '27',
#   '55',
#   '.491',
#   '7',
#   '17',
#   '.412',
#   '11',
#   '14',
#   '.786',
#   '4',
#   '19',
#   '10',
#   '2',
#   '4',
#   '8',
#   '20'],
#  '/cbb/boxscores/2018-02-14-18-michigan.htmlmichigan': ['/cbb/boxscores/2018-02-14-18-michigan.html',
#   'michigan',
#   '2018-02-14',
#   '',
#   'Iowa',
#   'W',
#   '74',
#   '59',
#   '28',
#   '67',
#   '.418',
#   '12',
#   '33',
#   '.364',
#   '6',
#   '12',
#   '.500',
#   '10',
#   '31',
#   '19',
#   '13',
#   '2',
#   '5',
#   '13',
#   '',
#   '25',
#   '52',
#   '.481',
#   '2',
#   '10',
#   '.200',
#   '7',
#   '9',
#   '.778',
#   '5',
#   '33',
#   '15',
#   '3',
#   '3',
#   '15',
#   '15'],
#  '/cbb/boxscores/2018-02-18-13-michigan.htmlmichigan': ['/cbb/boxscores/2018-02-18-13-michigan.html',
#   'michigan',
#   '2018-02-18',
#   '',
#   'Ohio State',
#   'W',
#   '74',
#   '62',
#   '25',
#   '52',
#   '.481',
#   '7',
#   '20',
#   '.350',
#   '17',
#   '24',
#   '.708',
#   '2',
#   '27',
#   '12',
#   '6',
#   '2',
#   '6',
#   '17',
#   '',
#   '24',
#   '58',
#   '.414',
#   '5',
#   '11',
#   '.455',
#   '9',
#   '19',
#   '.474',
#   '13',
#   '37',
#   '8',
#   '5',
#   '5',
#   '14',
#   '22'],
#  '/cbb/boxscores/2018-02-21-19-penn-state.htmlmichigan': ['/cbb/boxscores/2018-02-21-19-penn-state.html',
#   'michigan',
#   '2018-02-21',
#   '@',
#   'Penn State',
#   'W',
#   '72',
#   '63',
#   '23',
#   '51',
#   '.451',
#   '10',
#   '21',
#   '.476',
#   '16',
#   '19',
#   '.842',
#   '5',
#   '32',
#   '15',
#   '8',
#   '6',
#   '11',
#   '15',
#   '',
#   '25',
#   '59',
#   '.424',
#   '7',
#   '18',
#   '.389',
#   '6',
#   '11',
#   '.545',
#   '4',
#   '26',
#   '10',
#   '6',
#   '6',
#   '10',
#   '19'],
#  '/cbb/boxscores/2018-02-24-12-maryland.htmlmichigan': ['/cbb/boxscores/2018-02-24-12-maryland.html',
#   'michigan',
#   '2018-02-24',
#   '@',
#   'Maryland',
#   'W',
#   '85',
#   '61',
#   '29',
#   '57',
#   '.509',
#   '15',
#   '31',
#   '.484',
#   '12',
#   '16',
#   '.750',
#   '8',
#   '29',
#   '18',
#   '6',
#   '5',
#   '8',
#   '18',
#   '',
#   '21',
#   '55',
#   '.382',
#   '3',
#   '18',
#   '.167',
#   '16',
#   '20',
#   '.800',
#   '9',
#   '30',
#   '10',
#   '3',
#   '1',
#   '11',
#   '14'],
#  '/cbb/boxscores/2018-03-01-14-michigan.htmlmichigan': ['/cbb/boxscores/2018-03-01-14-michigan.html',
#   'michigan',
#   '2018-03-01',
#   'N',
#   'Iowa',
#   'W\xa0(1 OT)',
#   '77',
#   '71',
#   '28',
#   '62',
#   '.452',
#   '3',
#   '19',
#   '.158',
#   '18',
#   '32',
#   '.563',
#   '10',
#   '41',
#   '11',
#   '8',
#   '2',
#   '7',
#   '22',
#   '',
#   '27',
#   '65',
#   '.415',
#   '7',
#   '23',
#   '.304',
#   '10',
#   '18',
#   '.556',
#   '8',
#   '37',
#   '17',
#   '2',
#   '1',
#   '14',
#   '24'],
#  '/cbb/boxscores/2018-03-02-14-nebraska.htmlmichigan': ['/cbb/boxscores/2018-03-02-14-nebraska.html',
#   'michigan',
#   '2018-03-02',
#   'N',
#   'Nebraska',
#   'W',
#   '77',
#   '58',
#   '27',
#   '61',
#   '.443',
#   '11',
#   '23',
#   '.478',
#   '12',
#   '15',
#   '.800',
#   '12',
#   '38',
#   '12',
#   '4',
#   '6',
#   '9',
#   '20',
#   '',
#   '16',
#   '53',
#   '.302',
#   '4',
#   '16',
#   '.250',
#   '22',
#   '27',
#   '.815',
#   '6',
#   '27',
#   '5',
#   '3',
#   '8',
#   '10',
#   '18'],
#  '/cbb/boxscores/2018-03-03-14-michigan-state.htmlmichigan': ['/cbb/boxscores/2018-03-03-14-michigan-state.html',
#   'michigan',
#   '2018-03-03',
#   'N',
#   'Michigan State',
#   'W',
#   '75',
#   '64',
#   '21',
#   '47',
#   '.447',
#   '9',
#   '25',
#   '.360',
#   '24',
#   '33',
#   '.727',
#   '4',
#   '34',
#   '10',
#   '5',
#   '1',
#   '8',
#   '13',
#   '',
#   '24',
#   '63',
#   '.381',
#   '7',
#   '25',
#   '.280',
#   '9',
#   '10',
#   '.900',
#   '9',
#   '32',
#   '10',
#   '4',
#   '1',
#   '8',
#   '23'],
#  '/cbb/boxscores/2018-03-04-16-purdue.htmlmichigan': ['/cbb/boxscores/2018-03-04-16-purdue.html',
#   'michigan',
#   '2018-03-04',
#   'N',
#   'Purdue',
#   'W',
#   '75',
#   '66',
#   '26',
#   '52',
#   '.500',
#   '8',
#   '23',
#   '.348',
#   '15',
#   '25',
#   '.600',
#   '4',
#   '23',
#   '18',
#   '6',
#   '2',
#   '5',
#   '16',
#   '',
#   '25',
#   '55',
#   '.455',
#   '4',
#   '17',
#   '.235',
#   '12',
#   '17',
#   '.706',
#   '7',
#   '35',
#   '8',
#   '2',
#   '1',
#   '11',
#   '21'],
#  '/cbb/boxscores/2018-03-15-21-michigan.htmlmichigan': ['/cbb/boxscores/2018-03-15-21-michigan.html',
#   'michigan',
#   '2018-03-15',
#   'N',
#   'Montana',
#   'W',
#   '61',
#   '47',
#   '21',
#   '47',
#   '.447',
#   '5',
#   '16',
#   '.313',
#   '14',
#   '22',
#   '.636',
#   '5',
#   '35',
#   '11',
#   '4',
#   '3',
#   '13',
#   '14',
#   '',
#   '18',
#   '56',
#   '.321',
#   '3',
#   '15',
#   '.200',
#   '8',
#   '11',
#   '.727',
#   '8',
#   '33',
#   '7',
#   '7',
#   '2',
#   '12',
#   '21'],
#  '/cbb/boxscores/2018-03-17-21-michigan.htmlmichigan': ['/cbb/boxscores/2018-03-17-21-michigan.html',
#   'michigan',
#   '2018-03-17',
#   'N',
#   'Houston',
#   'W',
#   '64',
#   '63',
#   '21',
#   '59',
#   '.356',
#   '8',
#   '30',
#   '.267',
#   '14',
#   '20',
#   '.700',
#   '7',
#   '33',
#   '13',
#   '4',
#   '5',
#   '7',
#   '22',
#   '',
#   '20',
#   '54',
#   '.370',
#   '7',
#   '18',
#   '.389',
#   '16',
#   '22',
#   '.727',
#   '8',
#   '37',
#   '8',
#   '3',
#   '2',
#   '10',
#   '19'],
#  '/cbb/boxscores/2018-03-22-19-michigan.htmlmichigan': ['/cbb/boxscores/2018-03-22-19-michigan.html',
#   'michigan',
#   '2018-03-22',
#   'N',
#   'Texas A&M',
#   'W',
#   '99',
#   '72',
#   '39',
#   '63',
#   '.619',
#   '14',
#   '24',
#   '.583',
#   '7',
#   '8',
#   '.875',
#   '2',
#   '26',
#   '21',
#   '12',
#   '0',
#   '6',
#   '15',
#   '',
#   '32',
#   '67',
#   '.478',
#   '3',
#   '15',
#   '.200',
#   '5',
#   '10',
#   '.500',
#   '11',
#   '31',
#   '13',
#   '4',
#   '4',
#   '14',
#   '12'],
#  '/cbb/boxscores/2018-03-24-20-michigan.htmlmichigan': ['/cbb/boxscores/2018-03-24-20-michigan.html',
#   'michigan',
#   '2018-03-24',
#   'N',
#   'Florida State',
#   'W',
#   '58',
#   '54',
#   '19',
#   '49',
#   '.388',
#   '4',
#   '22',
#   '.182',
#   '16',
#   '24',
#   '.667',
#   '7',
#   '30',
#   '8',
#   '6',
#   '4',
#   '10',
#   '16',
#   '',
#   '16',
#   '51',
#   '.314',
#   '4',
#   '17',
#   '.235',
#   '18',
#   '20',
#   '.900',
#   '10',
#   '33',
#   '6',
#   '6',
#   '7',
#   '13',
#   '23'],
#  '/cbb/boxscores/2018-03-31-18-michigan.htmlmichigan': ['/cbb/boxscores/2018-03-31-18-michigan.html',
#   'michigan',
#   '2018-03-31',
#   'N',
#   'Loyola (IL)',
#   'W',
#   '69',
#   '57',
#   '25',
#   '59',
#   '.424',
#   '7',
#   '28',
#   '.250',
#   '12',
#   '18',
#   '.667',
#   '10',
#   '35',
#   '8',
#   '10',
#   '2',
#   '11',
#   '11',
#   '',
#   '22',
#   '51',
#   '.431',
#   '1',
#   '10',
#   '.100',
#   '12',
#   '14',
#   '.857',
#   '5',
#   '31',
#   '6',
#   '5',
#   '1',
#   '17',
#   '17'],
#  '/cbb/boxscores/2018-04-02-21-villanova.htmlmichigan': ['/cbb/boxscores/2018-04-02-21-villanova.html',
#   'michigan',
#   '2018-04-02',
#   'N',
#   'Villanova',
#   'L',
#   '62',
#   '79',
#   '24',
#   '55',
#   '.436',
#   '3',
#   '23',
#   '.130',
#   '11',
#   '18',
#   '.611',
#   '5',
#   '26',
#   '6',
#   '6',
#   '1',
#   '10',
#   '20',
#   '',
#   '27',
#   '57',
#   '.474',
#   '10',
#   '27',
#   '.370',
#   '15',
#   '20',
#   '.750',
#   '12',
#   '38',
#   '7',
#   '5',
#   '3',
#   '12',
#   '18']}
